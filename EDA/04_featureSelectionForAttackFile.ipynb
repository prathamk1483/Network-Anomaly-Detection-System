# %%
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import RandomForestRegressor
import sklearn as sk
import time
seconds = time.time()

# %%
def folder(f_name): #this function creates a folder named "feaure_pics" in the program directory.
    try:
        if not os.path.exists(f_name):
            os.makedirs(f_name)
    except OSError:
        print ("The folder could not be created!")

# %%
csv_files=os.listdir("attacks")# It creates a list of file names in the "attacks" folder.

# %%
# Headers of column
main_labels=["Flow Duration","Total Fwd Packets",   "Total Backward Packets","Total Length of Fwd Packets","Total Length of Bwd Packets","Fwd Packet Length Max","Fwd Packet Length Min",
   "Fwd Packet Length Mean","Fwd Packet Length Std","Bwd Packet Length Max","Bwd Packet Length Min","Bwd Packet Length Mean","Bwd Packet Length Std",
   "Flow Bytes/s","Flow Packets/s","Flow IAT Mean","Flow IAT Std","Flow IAT Max","Flow IAT Min","Fwd IAT Total","Fwd IAT Mean","Fwd IAT Std","Fwd IAT Max",
   "Fwd IAT Min","Bwd IAT Total","Bwd IAT Mean","Bwd IAT Std","Bwd IAT Max","Bwd IAT Min","Fwd PSH Flags","Bwd PSH Flags","Fwd URG Flags","Bwd URG Flags",
   "Fwd Header Length","Bwd Header Length","Fwd Packets/s","Bwd Packets/s","Min Packet Length","Max Packet Length","Packet Length Mean","Packet Length Std",
   "Packet Length Variance","FIN Flag Count","SYN Flag Count","RST Flag Count","PSH Flag Count","ACK Flag Count","URG Flag Count","CWE Flag Count",
   "ECE Flag Count","Down/Up Ratio","Average Packet Size","Avg Fwd Segment Size","Avg Bwd Segment Size","Fwd Avg Bytes/Bulk",
   "Fwd Avg Packets/Bulk","Fwd Avg Bulk Rate","Bwd Avg Bytes/Bulk","Bwd Avg Packets/Bulk","Bwd Avg Bulk Rate","Subflow Fwd Packets","Subflow Fwd Bytes",
   "Subflow Bwd Packets","Subflow Bwd Bytes","Init_Win_bytes_forward","Init_Win_bytes_backward","act_data_pkt_fwd",
   "min_seg_size_forward","Active Mean","Active Std","Active Max","Active Min",
    "Idle Mean","Idle Std","Idle Max", "Idle Min","Label"]

# %%
ths = open("importance_list_for_attack_files.csv", "w")
folder("./feaure_pics/")

# %%
for j in csv_files:
    df=pd.read_csv(".\\attacks\\"+j,usecols=main_labels)
    df=df.fillna(0)
    attack_or_not=[]
    for i in df["Label"]:#it changes the normal label to "1" and the attack tag to "0" for use in the machine learning algorithm
        if i =="BENIGN":
            attack_or_not.append(1)
        else:
            attack_or_not.append(0)           
    df["Label"]=attack_or_not

    y = df["Label"].values
    del df["Label"]
    X = df.values
    
    X = np.float32(X)
    X[np.isnan(X)] = 0
    X[np.isinf(X)] = 0
   

    #computing the feature importances
    forest = sk.ensemble.RandomForestRegressor(n_estimators=250,random_state=0)
    forest.fit(X, y)
    importances = forest.feature_importances_
    std = np.std([tree.feature_importances_ for tree in forest.estimators_],
                 axis=0)
    indices = np.argsort(importances)[::-1]
    refclasscol=list(df.columns.values)
    impor_bars = pd.DataFrame({'Features':refclasscol[0:20],'importance':importances[0:20]})
    impor_bars = impor_bars.sort_values('importance',ascending=False).set_index('Features')
    plt.rcParams['figure.figsize'] = (10, 5)
    impor_bars.plot.bar();
    #printing the feature importances  
    count=0
    fea_ture=j[0:-4]+"=["
    for i in impor_bars.index:
        fea_ture=fea_ture+"\""+str(i)+"\","
        count+=1
        if count==5:
            fea_ture=fea_ture[0:-1]+"]"
            break     
    print(j[0:-4],"importance list:")
    print(j[0:-4],"\n",impor_bars.head(20),"\n\n\n")
    print(fea_ture)
    plt.title(j[0:-4]+" Attack - Feature Importance")
    plt.ylabel('Importance')
    plt.savefig("./feaure_pics/"+j[0:-4]+".pdf",bbox_inches='tight', orientation = 'portrait', format = 'pdf')
    ths.write((  fea_ture ) )
    plt.tight_layout()
    plt.show()
    print("-----------------------------------------------------------------------------------------------\n\n\n\n")

    
print("mission accomplished!")
print("Total operation time: = ",time.time()- seconds ,"seconds")
ths.close()
# Out:
# Bot importance list:
# Bot
#                               importance
# Features
# Bwd Packet Length Mean         0.342542
# Flow IAT Min                   0.009379
# Flow Duration                  0.008872
# Flow IAT Std                   0.008243
# Fwd IAT Total                  0.005075
# Flow IAT Max                   0.002423
# Flow Bytes/s                   0.002375
# Flow IAT Mean                  0.001680
# Flow Packets/s                 0.000698
# Fwd Packet Length Mean         0.000603
# Total Length of Bwd Packets    0.000340
# Total Backward Packets         0.000182
# Bwd Packet Length Max          0.000151
# Fwd Packet Length Std          0.000122
# Fwd Packet Length Max          0.000121
# Total Length of Fwd Packets    0.000103
# Total Fwd Packets              0.000048
# Bwd Packet Length Std          0.000041
# Bwd Packet Length Min          0.000034
# Fwd Packet Length Min          0.000027
#
#
#
# Bot=["Bwd Packet Length Mean","Flow IAT Min","Flow Duration","Flow IAT Std","Fwd IAT Total"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# DDoS importance list:
# DDoS
#                               importance
# Features
# Fwd Packet Length Max          0.606616
# Total Length of Fwd Packets    0.189657
# Bwd Packet Length Min          0.000660
# Flow IAT Min                   0.000166
# Bwd Packet Length Mean         0.000152
# Total Backward Packets         0.000048
# Flow IAT Mean                  0.000044
# Flow Duration                  0.000041
# Flow IAT Max                   0.000036
# Flow Bytes/s                   0.000034
# Flow IAT Std                   0.000031
# Fwd IAT Total                  0.000029
# Flow Packets/s                 0.000023
# Fwd Packet Length Std          0.000019
# Fwd Packet Length Mean         0.000017
# Bwd Packet Length Max          0.000008
# Total Length of Bwd Packets    0.000008
# Fwd Packet Length Min          0.000004
# Bwd Packet Length Std          0.000004
# Total Fwd Packets              0.000003
#
#
#
# DDoS=["Fwd Packet Length Max","Total Length of Fwd Packets","Bwd Packet Length Min","Flow IAT Min","Bwd Packet Length Mean"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# DoS GoldenEye importance list:
# DoS GoldenEye
#                               importance
# Features
# Bwd Packet Length Std          0.580671
# Flow IAT Min                   0.281685
# Flow IAT Mean                  0.025680
# Flow IAT Std                   0.021811
# Total Backward Packets         0.008223
# Fwd Packet Length Min          0.001126
# Fwd IAT Total                  0.000821
# Flow Duration                  0.000762
# Flow IAT Max                   0.000700
# Flow Packets/s                 0.000435
# Fwd Packet Length Max          0.000367
# Total Length of Fwd Packets    0.000322
# Bwd Packet Length Mean         0.000265
# Fwd Packet Length Mean         0.000212
# Flow Bytes/s                   0.000127
# Total Length of Bwd Packets    0.000051
# Total Fwd Packets              0.000024
# Bwd Packet Length Max          0.000017
# Fwd Packet Length Std          0.000016
# Bwd Packet Length Min          0.000008
#
#
#
# DoS GoldenEye=["Bwd Packet Length Std","Flow IAT Min","Flow IAT Mean","Flow IAT Std","Total Backward Packets"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# DoS Hulk importance list:
# DoS Hulk
#                                 importance
# Features
# Bwd Packet Length Std        5.851379e-01
# Flow Duration                1.910698e-03
# Flow IAT Min                 1.806572e-03
# Total Length of Bwd Packets  6.116277e-04
# Total Backward Packets       3.491883e-04
# Fwd IAT Total                1.865096e-04
# Flow IAT Mean                1.004820e-04
# Flow IAT Max                 9.578825e-05
# Total Fwd Packets            7.723729e-05
# Flow IAT Std                 7.096731e-05
# Flow Packets/s               6.880990e-05
# Flow Bytes/s                 2.527565e-05
# Bwd Packet Length Mean       1.713118e-05
# Bwd Packet Length Max        1.197046e-05
# Bwd Packet Length Min        9.129955e-06
# Fwd Packet Length Max        9.016190e-06
# Fwd Packet Length Std        4.385150e-06
# Total Length of Fwd Packets  2.672369e-06
# Fwd Packet Length Mean       2.425675e-06
# Fwd Packet Length Min        2.863170e-07
#
#
#
# DoS Hulk=["Bwd Packet Length Std","Flow Duration","Flow IAT Min","Total Length of Bwd Packets","Total Backward Packets"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# DoS Slowhttptest importance list:
# DoS Slowhttptest
#                               importance
# Features
# Flow IAT Mean                  0.652339
# Fwd Packet Length Min          0.109482
# Bwd Packet Length Std          0.044803
# Total Length of Bwd Packets    0.019314
# Bwd Packet Length Mean         0.018635
# Bwd Packet Length Max          0.007849
# Flow IAT Min                   0.002961
# Fwd Packet Length Std          0.002037
# Total Fwd Packets              0.001284
# Fwd Packet Length Mean         0.001259
# Flow Duration                  0.000551
# Bwd Packet Length Min          0.000544
# Flow IAT Max                   0.000476
# Total Length of Fwd Packets    0.000358
# Fwd IAT Total                  0.000354
# Total Backward Packets         0.000208
# Flow Bytes/s                   0.000203
# Fwd Packet Length Max          0.000138
# Flow IAT Std                   0.000118
# Flow Packets/s                 0.000097
#
#
#
# DoS Slowhttptest=["Flow IAT Mean","Fwd Packet Length Min","Bwd Packet Length Std","Total Length of Bwd Packets","Bwd Packet Length Mean"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# DoS slowloris importance list:
# DoS slowloris
#                               importance
# Features
# Flow IAT Mean                  0.476018
# Bwd Packet Length Mean         0.087205
# Total Length of Bwd Packets    0.042686
# Total Fwd Packets              0.023853
# Fwd Packet Length Std          0.002802
# Bwd Packet Length Std          0.001912
# Bwd Packet Length Max          0.001636
# Flow IAT Min                   0.001404
# Fwd IAT Total                  0.001365
# Flow Bytes/s                   0.001113
# Total Backward Packets         0.000550
# Fwd Packet Length Max          0.000525
# Fwd Packet Length Mean         0.000399
# Flow Duration                  0.000373
# Flow IAT Max                   0.000362
# Total Length of Fwd Packets    0.000339
# Flow IAT Std                   0.000251
# Flow Packets/s                 0.000161
# Fwd Packet Length Min          0.000099
# Bwd Packet Length Min          0.000048
#
#
#
# DoS slowloris=["Flow IAT Mean","Bwd Packet Length Mean","Total Length of Bwd Packets","Total Fwd Packets","Fwd Packet Length Std"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# FTP-Patator importance list:
# FTP-Patator
#                               importance
# Features
# Fwd Packet Length Max          0.334858
# Fwd Packet Length Mean         0.068488
# Fwd Packet Length Std          0.028412
# Total Fwd Packets              0.000430
# Total Length of Bwd Packets    0.000290
# Flow IAT Min                   0.000240
# Flow Duration                  0.000201
# Flow IAT Max                   0.000157
# Bwd Packet Length Std          0.000105
# Bwd Packet Length Max          0.000087
# Flow IAT Mean                  0.000081
# Total Length of Fwd Packets    0.000077
# Bwd Packet Length Mean         0.000065
# Flow Packets/s                 0.000062
# Total Backward Packets         0.000055
# Fwd IAT Total                  0.000042
# Flow IAT Std                   0.000027
# Fwd Packet Length Min          0.000021
# Flow Bytes/s                   0.000011
# Bwd Packet Length Min          0.000003
#
#
#
# FTP-Patator=["Fwd Packet Length Max","Fwd Packet Length Mean","Fwd Packet Length Std","Total Fwd Packets","Total Length of Bwd Packets"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# Heartbleed importance list:
# Heartbleed
#                               importance
# Features
# Flow IAT Min                      0.052
# Bwd Packet Length Mean            0.052
# Total Backward Packets            0.048
# Bwd Packet Length Max             0.048
# Total Length of Bwd Packets       0.044
# Total Fwd Packets                 0.040
# Bwd Packet Length Std             0.032
# Flow Duration                     0.024
# Fwd IAT Total                     0.016
# Total Length of Fwd Packets       0.008
# Fwd Packet Length Mean            0.008
# Fwd Packet Length Max             0.004
# Bwd Packet Length Min             0.000
# Fwd Packet Length Std             0.000
# Fwd Packet Length Min             0.000
# Flow Bytes/s                      0.000
# Flow IAT Mean                     0.000
# Flow Packets/s                    0.000
# Flow IAT Max                      0.000
# Flow IAT Std                      0.000
#
#
#
# Heartbleed=["Flow IAT Min","Bwd Packet Length Mean","Total Backward Packets","Bwd Packet Length Max","Total Length of Bwd Packets"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# Infiltration importance list:
# Infiltration
#                               importance
# Features
# Fwd Packet Length Mean         0.092935
# Flow Duration                  0.074129
# Flow IAT Max                   0.029664
# Total Backward Packets         0.028115
# Fwd Packet Length Std          0.019267
# Total Length of Fwd Packets    0.015870
# Flow IAT Mean                  0.012649
# Bwd Packet Length Mean         0.007748
# Flow IAT Min                   0.007478
# Flow Bytes/s                   0.006957
# Fwd Packet Length Max          0.006059
# Fwd IAT Total                  0.005758
# Bwd Packet Length Max          0.003936
# Bwd Packet Length Std          0.003485
# Flow Packets/s                 0.003194
# Flow IAT Std                   0.002445
# Bwd Packet Length Min          0.002103
# Total Fwd Packets              0.001674
# Total Length of Bwd Packets    0.001277
# Fwd Packet Length Min          0.000408
#
#
#
# Infiltration=["Fwd Packet Length Mean","Flow Duration","Flow IAT Max","Total Backward Packets","Fwd Packet Length Std"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# PortScan importance list:
# PortScan
#                               importance
# Features
# Flow Bytes/s                   0.317205
# Total Length of Fwd Packets    0.302504
# Bwd Packet Length Std          0.000345
# Flow Duration                  0.000263
# Flow IAT Mean                  0.000232
# Flow IAT Max                   0.000221
# Fwd IAT Total                  0.000199
# Fwd Packet Length Max          0.000099
# Total Length of Bwd Packets    0.000052
# Fwd Packet Length Std          0.000051
# Bwd Packet Length Min          0.000048
# Bwd Packet Length Mean         0.000041
# Bwd Packet Length Max          0.000035
# Fwd Packet Length Mean         0.000028
# Flow Packets/s                 0.000020
# Total Fwd Packets              0.000017
# Flow IAT Min                   0.000015
# Total Backward Packets         0.000013
# Flow IAT Std                   0.000012
# Fwd Packet Length Min          0.000003
#
#
#
# PortScan=["Flow Bytes/s","Total Length of Fwd Packets","Bwd Packet Length Std","Flow Duration","Flow IAT Mean"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# SSH-Patator importance list:
# SSH-Patator
#                               importance
# Features
# Fwd Packet Length Max          0.000670
# Flow IAT Mean                  0.000610
# Total Length of Fwd Packets    0.000509
# Flow IAT Max                   0.000486
# Flow Packets/s                 0.000455
# Flow IAT Min                   0.000443
# Flow Duration                  0.000360
# Fwd Packet Length Mean         0.000351
# Flow IAT Std                   0.000307
# Fwd IAT Total                  0.000253
# Total Backward Packets         0.000126
# Flow Bytes/s                   0.000126
# Fwd Packet Length Std          0.000076
# Bwd Packet Length Max          0.000055
# Bwd Packet Length Mean         0.000044
# Total Length of Bwd Packets    0.000044
# Fwd Packet Length Min          0.000034
# Total Fwd Packets              0.000029
# Bwd Packet Length Std          0.000024
# Bwd Packet Length Min          0.000022
#
#
#
# SSH-Patator=["Fwd Packet Length Max","Flow IAT Mean","Total Length of Fwd Packets","Flow IAT Max","Flow Packets/s"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# Web Attack importance list:
# Web Attack
#                               importance
# Features
# Total Length of Fwd Packets    0.008445
# Bwd Packet Length Std          0.003804
# Flow Bytes/s                   0.002400
# Bwd Packet Length Max          0.002394
# Flow IAT Min                   0.001701
# Flow IAT Max                   0.001529
# Fwd Packet Length Mean         0.001443
# Flow Duration                  0.000968
# Fwd Packet Length Std          0.000882
# Total Fwd Packets              0.000720
# Flow IAT Mean                  0.000654
# Flow Packets/s                 0.000605
# Fwd Packet Length Max          0.000518
# Total Length of Bwd Packets    0.000421
# Fwd IAT Total                  0.000224
# Total Backward Packets         0.000213
# Flow IAT Std                   0.000197
# Bwd Packet Length Mean         0.000130
# Bwd Packet Length Min          0.000013
# Fwd Packet Length Min          0.000000
#
#
#
# Web Attack=["Total Length of Fwd Packets","Bwd Packet Length Std","Flow Bytes/s","Bwd Packet Length Max","Flow IAT Min"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# mission accomplished!
# Total operation time: =  4751.952135801315 seconds
